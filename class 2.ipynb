# %%
# Supervised learning




ndarray

# %%
# matplotbib

import numpy as np
# array()

a = np.array([1, 2, 3, 4])
# Out:
# 1

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a)

# %%
a = np.array([12, 3, 5, 6, 3])
b = np.array([34, 32, 37, 39, 40])

# %%
plt.scatter(a, b, marker = "*")

# %%
# supervised learning...
1) Simple linear regression
2) Muti linear regression

# %%
 y = mx + b

    y = depened variable (pkg)
    m = slope
    x = data(future value)
    b = offset
    
    m , b

# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x = data.iloc[:, 0:1]

# %%
x
# Out:
#      Duration
# 0          60
# 1          60
# 2          60
# 3          45
# 4          45
# ..        ...
# 164        60
# 165        60
# 166        60
# 167        75
# 168        75
#
# [169 rows x 1 columns]

# %%
y = data.iloc[:, 2:3]

# %%
y
# Out:
#      Maxpulse
# 0         130
# 1         145
# 2         135
# 3         175
# 4         148
# ..        ...
# 164       140
# 165       145
# 166       145
# 167       150
# 168       150
#
# [169 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
obj = LinearRegression()

# %%
obj
# Out:
# LinearRegression()

# %%
obj.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
obj
# Out:
# LinearRegression()

# %%
y = mx + b
# Out:
# LinearRegression()

# %%
m = obj.coef_

b = obj.intercept_

# %%
m
# Out:
# array([[0.01290311]])

# %%
y = m * 270 + b

# %%
y
# Out:
# array([[136.90989296]])

# %%
y_test
# Out:
#      Maxpulse
# 79        131
# 151       129
# 105       128
# 51        146
# 91        137
# 59        152
# 157       120
# 50        136
# 30        115
# 144       170
# 119       124
# 163       140
# 84        120
# 165       145
# 142       120
# 20        131
# 137       137
# 86        136
# 62        135
# 127       127
# 31        112
# 97        168
# 74        146
# 130       134
# 13        132
# 69        143
# 61        137
# 101       110
# 44        131
# 26        118
# 92        107
# 110       124
# 3         175
# 106       120

# %%
https://www.kaggle.com/datasets
