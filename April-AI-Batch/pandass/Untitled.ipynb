# %%
import pandas as pd

# %%
data = pd.read_csv("exams.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 995                    none          73             70             65
# 996               completed          85             91             92
# 997                    none          32             35             41
# 998                    none          73             74             82
# 999               completed          65             60             62

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.sample()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 970  female        group D            some high school  standard
#
#     test preparation course  math score  reading score  writing score
# 970               completed          85            100             97

# %%
data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# ...

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.396000      69.002000      67.738000
# std      15.402871      14.737272      15.600985
# min      13.000000      27.000000      23.000000
# 25%      56.000000      60.000000      58.000000
# 50%      66.500000      70.000000      68.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
# data.

# %%
data1 = pd.read_csv("Counselor Profile  Admin Dashboard (3).csv")

# %%
data1
# Out:
#     #       User ID      Student Name  Phone Number Course Type  \
# 0   1  MOH202400286       Isha thakur     623080176     Premium
# 1  22  MOH202400207  Vishavjeet Singh    6006025046     Premium
#
#                Admission Date
# 0   April 12, 2024, 1:51 p.m.
# 1  April 10, 2024, 12:46 p.m.

# %%
data2 = pd.read_csv("Counselor Profile  Admin Dashboard (4).csv")

# %%
data2
# Out:
#     #       User ID       Student Name  Phone Number Course Type  \
# 0   2  MOH202400275             Yuvraj    8168585914    Platinum
# 1   3  MOH202400272    Harmandeep kaur    8283956075    Platinum
# 2   4  MOH202400252  R Ananthakrishnan    9074856179    Platinum
# 3  11  MOH202400219    Prajval mahajan    7889528100    Platinum
# 4  12  MOH202400218             Yuvraj    7719668792    Platinum
# 5  32  MOH202400192      Arshdeep kaur    8968565337    Platinum
# 6  34  MOH202400190         Vivek Rana    8219692366    Platinum
# 7  35  MOH202400189       Nimrat Singh    7453000042    Platinum
#
#                Admission Date
# 0   April 11, 2024, 1:05 p.m.
# 1  April 11, 2024, 12:31 p.m.
# 2   April 11, 2024, 9:32 a.m.
# 3   April 10, 2024, 1:13 p.m.
# 4   April 10, 2024, 1:02 p.m.
# 5  April 10, 2024, 12:17 p.m.
# 6  April 10, 2024, 12:11 p.m.
# 7  April 10, 2024, 12:08 p.m.

# %%
# concatenate()

# %%
pd.concat([data1, data2])
# Out:
#     #       User ID       Student Name  Phone Number Course Type  \
# 0   1  MOH202400286        Isha thakur     623080176     Premium
# 1  22  MOH202400207   Vishavjeet Singh    6006025046     Premium
# 0   2  MOH202400275             Yuvraj    8168585914    Platinum
# 1   3  MOH202400272    Harmandeep kaur    8283956075    Platinum
# 2   4  MOH202400252  R Ananthakrishnan    9074856179    Platinum
# 3  11  MOH202400219    Prajval mahajan    7889528100    Platinum
# 4  12  MOH202400218             Yuvraj    7719668792    Platinum
# 5  32  MOH202400192      Arshdeep kaur    8968565337    Platinum
# 6  34  MOH202400190         Vivek Rana    8219692366    Platinum
# 7  35  MOH202400189       Nimrat Singh    7453000042    Platinum
#
#                Admission Date
# 0   April 12, 2024, 1:51 p.m.
# 1  April 10, 2024, 12:46 p.m.
# 0   April 11, 2024, 1:05 p.m.
# 1  April 11, 2024, 12:31 p.m.
# 2   April 11, 2024, 9:32 a.m.
# 3   April 10, 2024, 1:13 p.m.
# 4   April 10, 2024, 1:02 p.m.
# ...

# %%
pd.merge(data1, data2, on = ("User ID", "Student Name"), how = "outer")
# Out:
#     #_x       User ID       Student Name  Phone Number_x Course Type_x  \
# 0   1.0  MOH202400286        Isha thakur    6.230802e+08       Premium
# 1  22.0  MOH202400207   Vishavjeet Singh    6.006025e+09       Premium
# 2   NaN  MOH202400275             Yuvraj             NaN           NaN
# 3   NaN  MOH202400272    Harmandeep kaur             NaN           NaN
# 4   NaN  MOH202400252  R Ananthakrishnan             NaN           NaN
# 5   NaN  MOH202400219    Prajval mahajan             NaN           NaN
# 6   NaN  MOH202400218             Yuvraj             NaN           NaN
# 7   NaN  MOH202400192      Arshdeep kaur             NaN           NaN
# 8   NaN  MOH202400190         Vivek Rana             NaN           NaN
# 9   NaN  MOH202400189       Nimrat Singh             NaN           NaN
#
#              Admission Date_x   #_y  Phone Number_y Course Type_y  \
# 0   April 12, 2024, 1:51 p.m.   NaN             NaN           NaN
# ...

# %%
data = pd.read_csv("exams.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.sort_values("parental level of education")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 499    male        group B          associate's degree      standard
# 796    male        group D          associate's degree  free/reduced
# 152  female        group B          associate's degree      standard
# 588  female        group B          associate's degree      standard
# 154  female        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 325  female        group C            some high school      standard
# 820  female        group C            some high school      standard
# 135    male        group C            some high school  free/reduced
# 801  female        group C            some high school      standard
# 715    male        group D            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
data[["math score", "reading score"]]
# Out:
#      math score  reading score
# 0            67             67
# 1            40             59
# 2            59             60
# 3            77             78
# 4            78             73
# ..          ...            ...
# 995          73             70
# 996          85             91
# 997          32             35
# 998          73             74
# 999          65             60
#
# [1000 rows x 2 columns]

# %%
data.get([5, 6])

# %%
data.iloc[:, [5, 6]]
# Out:
#      math score  reading score
# 0            67             67
# 1            40             59
# 2            59             60
# 3            77             78
# 4            78             73
# ..          ...            ...
# 995          73             70
# 996          85             91
# 997          32             35
# 998          73             74
# 999          65             60
#
# [1000 rows x 2 columns]

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
type(data["math score"])
# Out:
# pandas.core.series.Series

# %%
# convert series to numpy array

xyz = data["math score"].values

# %%
xyz[:10]
# Out:
# array([67, 40, 59, 77, 78, 63, 62, 93, 63, 47], dtype=int64)

# %%
type(xyz)
# Out:
# numpy.ndarray

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data["gender"].str.upper()
# Out:
# 0        MALE
# 1      FEMALE
# 2        MALE
# 3        MALE
# 4        MALE
#         ...
# 995      MALE
# 996      MALE
# 997    FEMALE
# 998    FEMALE
# 999      MALE
# Name: gender, Length: 1000, dtype: object

# %%
data.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
