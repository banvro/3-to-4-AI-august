# %%
import pandas as pd

# %%
# how to load data in pandas.....

# %%
data = pd.read_csv("coustmerdata.csv")
# data = pd.read_csv("C:\\Users\\17nru\\OneDrive\\Desktop\\ai classes\\coustmerdata.csv")

# %%
data
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG    4/8/1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES   8/12/1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG    7/4/1958             M
# 18144        29480   MRS.       NINA     RAJI  11/10/1960             S
# 18145        29481    MR.       IVAN     SURI    1/5/1960             S
# 18146        29482    MR.    CLAYTON    ZHANG    3/5/1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO   12/8/1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
data2 = pd.read_csv("exams.csv")

# %%
data2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data2.to_string()
# Out:
# "     gender race/ethnicity parental level of education         lunch test preparation course  math score  reading score  writing score\n0      male        group A                 high school      standard               completed          67             67             63\n1    female        group D            some high school  free/reduced                    none          40             59             55\n2      male        group E                some college  free/reduced                    none          59             60             50\n3      male        group B                 high school      standard                    none          77             78             68\n4      male        group E          associate's degree      standard               completed          78             73             68\n5    female        group D                 high school      standard                    none          63             77             76\n6    female        group A           bachelor
# ...

# %%
data2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# head() -> return top 5 rows

# %%
data2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
data2.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# ...

# %%
# tail() -> return last 5 reacord....

# %%
data2.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 995                    none          73             70             65
# 996               completed          85             91             92
# 997                    none          32             35             41
# 998                    none          73             74             82
# 999               completed          65             60             62

# %%
data2.tail(7)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 993  female        group A          associate's degree      standard
# 994    male        group E                 high school  free/reduced
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 993                    none          58             54             58
# 994               completed          86             82             75
# 995                    none          73             70             65
# 996               completed          85             91             92
# ...

# %%
# sample() -> return random rows

# %%
data2.sample()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 420  female        group A           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 420                    none          57             71             63

# %%
data2.sample(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 993  female        group A          associate's degree      standard
# 649  female        group B                 high school  free/reduced
# 390  female        group C                some college      standard
# 466  female        group B                some college  free/reduced
# 955    male        group D          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 993                    none          58             54             58
# 649                    none          30             43             40
# 390                    none          63             62             64
# 466               completed          74             85             82
# 955               completed          83             76             81

# %%
# info() -----> return information about dataset

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data2.head(3)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50

# %%
data2["parental level of education"]
# Out:
# 0             high school
# 1        some high school
# 2            some college
# 3             high school
# 4      associate's degree
#               ...
# 995           high school
# 996    associate's degree
# 997      some high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: object

# %%
data2["parental level of education"][0]
# Out:
# 'high school'

# %%
data2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data2.loc[995]
# Out:
# gender                                male
# race/ethnicity                     group C
# parental level of education    high school
# lunch                             standard
# test preparation course               none
# math score                              73
# reading score                           70
# writing score                           65
# Name: 995, dtype: object

# %%
# iloc[]

# %%
# datasetname.iloc[rows, columns]

# %%
data2.iloc[[2, 4], :]
# Out:
#   gender race/ethnicity parental level of education         lunch  \
# 2   male        group E                some college  free/reduced
# 4   male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 2                    none          59             60             50
# 4               completed          78             73             68

# %%
data2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
data2.iloc[:, [2, 5, 7]]
# Out:
#     parental level of education  math score  writing score
# 0                   high school          67             63
# 1              some high school          40             55
# 2                  some college          59             50
# 3                   high school          77             68
# 4            associate's degree          78             68
# ..                          ...         ...            ...
# 995                 high school          73             65
# 996          associate's degree          85             92
# 997            some high school          32             41
# 998                some college          73             82
# 999                some college          65             62
#
# [1000 rows x 3 columns]

# %%
data2.iloc[:10, [2, 5, 7]]
# Out:
#   parental level of education  math score  writing score
# 0                 high school          67             63
# 1            some high school          40             55
# 2                some college          59             50
# 3                 high school          77             68
# 4          associate's degree          78             68
# 5                 high school          63             76
# 6           bachelor's degree          62             63
# 7                some college          93             84
# 8                 high school          63             65
# 9                some college          47             45

# %%
data2.iloc[:10, [2, 5, -1]]
# Out:
#   parental level of education  math score  writing score
# 0                 high school          67             63
# 1            some high school          40             55
# 2                some college          59             50
# 3                 high school          77             68
# 4          associate's degree          78             68
# 5                 high school          63             76
# 6           bachelor's degree          62             63
# 7                some college          93             84
# 8                 high school          63             65
# 9                some college          47             45

# %%
data2.iloc[500:600, :]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 500  female        group B                 high school  free/reduced
# 501  female        group C          associate's degree      standard
# 502    male        group D          associate's degree      standard
# 503    male        group D                 high school      standard
# 504  female        group C                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 595  female        group B                some college      standard
# 596  female        group B                 high school  free/reduced
# 597  female        group A                some college      standard
# 598    male        group A            some high school  free/reduced
# 599  female        group C            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data2["math score"]
# Out:
# 0      67
# 1      40
# 2      59
# 3      77
# 4      78
#        ..
# 995    73
# 996    85
# 997    32
# 998    73
# 999    65
# Name: math score, Length: 1000, dtype: int64

# %%
data2["math score"].mean()
# Out:
# 66.396

# %%
data2["math score"].median()
# Out:
# 66.5

# %%
data2["math score"].mode()
# Out:
# 0    63
# Name: math score, dtype: int64
